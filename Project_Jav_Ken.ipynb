# %%
import requests # to make TMDB API calls
import locale # to format currency as USD
locale.setlocale( locale.LC_ALL, '' )

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter # to format currency on charts axis


# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb

plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['font.serif'] = ['SimHei']
sb.set_style("darkgrid",{"font.sans-serif":['simhei', 'Arial']})

# %%
response =

# %%
print(response.status_code)
# Out:
# 200

# %%
result = response.json()
titles = result['results']

# %%
print(titles[0])
# Out:
# {'adult': False, 'backdrop_path': '/hmNKg4hN2BYftaCJGdKHyETFFki.jpg', 'genre_ids': [10752, 36, 18, 28], 'id': 508935, 'original_language': 'zh', 'original_title': '八佰', 'overview': 'In 1937, eight hundred Chinese soldiers fight under siege from a warehouse in the middle of the Shanghai battlefield, completely surrounded by the Japanese army.', 'popularity': 15.989, 'poster_path': '/2tuJiQQUJNZgEmBgBfNVaYvAnPT.jpg', 'release_date': '2020-08-14', 'title': 'The Eight Hundred', 'video': False, 'vote_average': 7.3, 'vote_count': 54}

# %%
print(titles[0].keys())
# Out:
# dict_keys(['adult', 'backdrop_path', 'genre_ids', 'id', 'original_language', 'original_title', 'overview', 'popularity', 'poster_path', 'release_date', 'title', 'video', 'vote_average', 'vote_count'])

# %% [markdown]
# | Key        |
# | --------------: |
# | adult        |
# | backdrop_path        |
# | genre_ids       |
# | id       |
# | original_language        |
# | original_title        |
# | overview        |
# | popularity        |
# | poster_path        |
# | release_date        |
# | title        |
# | video        |
# | vote_average    |
# | vote_count      |

# %%
new_dict = {}

# %%
for i in range(len(titles)) :
    print(titles[i]['original_title'])
    new_dict[str(titles[i]['original_title'])] = [titles[i]['popularity'], titles[i]['release_date'], titles[i]['vote_count']]
# Out:
# 八佰
# Metallica: WorldWired Tour - Live in Manchester, England - June 18, 2019
# Bad Boys for Life
# 劇場版「鬼滅の刃」無限列車編
# Tenet
# Sonic the Hedgehog
# Dolittle
# 姜子牙
# Birds of Prey (and the Fantabulous Emancipation of One Harley Quinn)
# Wonder Woman 1984
# Onward
# The Croods: A New Age
# The Invisible Man
# The Call of the Wild
# Manbaby Cries Because He Isn't Added to Discord Chat (Gone Wrong)
# Jiu Jitsu
# 晴雅集
# Soul
# Mulan
# Tolo Tolo

# %%
new_dict
# Out:
# {'八佰': [15.989, '2020-08-14', 54],
#  'Metallica: WorldWired Tour - Live in Manchester, England - June 18, 2019': [4.277,
#   '2020-06-08',
#   0],
#  'Bad Boys for Life': [468.919, '2020-01-15', 6052],
#  '劇場版「鬼滅の刃」無限列車編': [205.503, '2020-10-16', 479],
#  'Tenet': [637.695, '2020-08-22', 4620],
#  'Sonic the Hedgehog': [112.431, '2020-02-12', 6599],
#  'Dolittle': [42.679, '2020-01-01', 2451],
#  '姜子牙': [15.9, '2020-10-01', 9],
#  'Birds of Prey (and the Fantabulous Emancipation of One Harley Quinn)': [607.49,
#   '2020-02-05',
#   7063],
#  'Wonder Woman 1984': [1967.361, '2020-12-16', 4117],
#  'Onward': [71.019, '2020-02-29', 3981],
#  'The Croods: A New Age': [740.365, '2020-11-25', 1663],
#  'The Invisible Man': [39.747, '2020-02-26', 3498],
#  'The Call of the Wild': [62.184, '2020-02-19', 2356],
#  "Manbaby Cries Because He Isn't Added to Discord Chat (Gone Wrong)": [1.167,
#   '2020-02-19',
#   1],
#  'Jiu Jitsu': [840.243, '2020-11-20', 306],
#  '晴雅集': [24.487, '2020-12-24', 38],
#  'Soul': [821.763, '2020-12-25', 5147],
#  'Mulan': [295.034, '2020-09-04', 4417],
#  'Tolo Tolo': [11.346, '2020-01-01', 889]}

# %%
data = pd.DataFrame.from_dict(new_dict, orient = 'index', columns = ['popularity', 'release-date', 'vote count'])
data
# Out:
#                                                     popularity release-date  \
# 八佰                                                      15.989   2020-08-14
# Metallica: WorldWired Tour - Live in Manchester...       4.277   2020-06-08
# Bad Boys for Life                                      468.919   2020-01-15
# 劇場版「鬼滅の刃」無限列車編                                         205.503   2020-10-16
# Tenet                                                  637.695   2020-08-22
# Sonic the Hedgehog                                     112.431   2020-02-12
# Dolittle                                                42.679   2020-01-01
# 姜子牙                                                     15.900   2020-10-01
# Birds of Prey (and the Fantabulous Emancipation...     607.490   2020-02-05
# Wonder Woman 1984                                     1967.361   2020-12-16
# Onward                                                  71.019   2020-02-29
# The Croods: A New Age                                  740.365   2020-11-25
# The Invisible Man                                       39.747   2020-02-26
# The Call of the Wild                                    62.184   2020-02-19
# Manbaby Cries Because He Isn't Added to Discord...       1.167   2020-02-19
# Jiu Jitsu                                              840.243   2020-11-20
# 晴雅集                                                     24.487   2020-12-24
# Soul                                                   821.763   2020-12-25
# Mulan                                                  295.034   2020-09-04
# Tolo Tolo                                               11.346   2020-01-01
#
#                                                     vote count
# 八佰                                                          54
# Metallica: WorldWired Tour - Live in Manchester...           0
# Bad Boys for Life                                         6052
# 劇場版「鬼滅の刃」無限列車編                                             479
# Tenet                                                     4620
# Sonic the Hedgehog                                        6599
# Dolittle                                                  2451
# 姜子牙                                                          9
# Birds of Prey (and the Fantabulous Emancipation...        7063
# Wonder Woman 1984                                         4117
# Onward                                                    3981
# The Croods: A New Age                                     1663
# The Invisible Man                                         3498
# The Call of the Wild                                      2356
# Manbaby Cries Because He Isn't Added to Discord...           1
# Jiu Jitsu                                                  306
# 晴雅集                                                         38
# Soul                                                      5147
# Mulan                                                     4417
# Tolo Tolo                                                  889

# %% [markdown]
# ---
# ## Finding highest revenue
# https://dev.to/m0nica/how-to-use-the-tmdb-api-to-find-films-with-the-highest-revenue-82p

# %%
# define column names for our new dataframe
columns = ['film', 'revenue']

# create dataframe with film and revenue columns
df = pd.DataFrame(columns=columns)

# %%
 titles[1]
# Out:
# {'adult': False,
#  'backdrop_path': '/ddygUzXBHGqnlBPcUI70ih7QOW0.jpg',
#  'genre_ids': [10402],
#  'id': 715904,
#  'original_language': 'en',
#  'original_title': 'Metallica: WorldWired Tour - Live in Manchester, England - June 18, 2019',
#  'overview': "Filmed at Etihad Stadium in Manchester, England on June 18, 2019. This concert is part of the WorldWired Tour by American heavy metal band Metallica in support of their tenth studio album Hardwired... to Self-Destruct, which was released on November 18, 2016. It is also their first worldwide tour after the World Magnetic Tour six years earlier. Set-List: 1. Hardwired / 2. The Memory Remains (with extended outro) / 3. Disposable Heroes / 4. The God That Failed / 5. The Unforgiven / 6. Here Comes Revenge / 7. Moth Into Flame / 8. Sad but True / 9. Welcome Home (Sanitarium) (followed by Kirk & Rob's solos incl. 'I Wanna Be Adored', 'ManUNkind' & 'Orion') / 10. St. Anger / 11. One / 12. Master of Puppets / 13. For Whom the Bell Tolls / 14. Creeping Death / 15. Seek & Destroy / 16. Lords of Summer / 17. Nothing Else Matters / 18. Enter Sandman (with 'The Frayed Ends of Sanity' outro).",
#  'popularity': 4.277,
#  'poster_path': '/ehM3D3KKo2OUxVVBFif1OJbtqGP.jpg',
#  'release_date': '2020-06-08',
#  'title': 'Metallica: WorldWired Tour - Live in Manchester, England - June 18, 2019',
#  'video': False,
#  'vote_average': 0,
#  'vote_count': 0}

# %%
for i in range(len(titles)) :
    film_revenue = requests.get('https://api.themoviedb.org/3/movie/'+ str(titles[i]['id']) +'?api_key='+ api_token+'&language=en-US')
    film_revenue = film_revenue.json()
    df.loc[len(df)]=[titles[i]['original_title'],film_revenue['revenue']] # store title and revenue in our dataframe

# %%
df
# Out:
#                                                  film    revenue
# 0                                                  八佰  460919368
# 1   Metallica: WorldWired Tour - Live in Mancheste...  426900000
# 2                                   Bad Boys for Life  426505244
# 3                                      劇場版「鬼滅の刃」無限列車編  399180000
# 4                                               Tenet  363129000
# 5                                  Sonic the Hedgehog  306766470
# 6                                            Dolittle  245692007
# 7                                                 姜子牙  240656068
# 8   Birds of Prey (and the Fantabulous Emancipatio...  201858461
# 9                                   Wonder Woman 1984  159533000
# 10                                             Onward  141592359
# 11                              The Croods: A New Age  135076090
# 12                                  The Invisible Man  130234661
# 13                               The Call of the Wild  107604626
# 14  Manbaby Cries Because He Isn't Added to Discor...   99000000
# 15                                          Jiu Jitsu   74000000
# 16                                                晴雅集   69000000
# 17                                               Soul   57400000
# 18                                              Mulan   57000000
# 19                                          Tolo Tolo   52186426

# %%
f = plt.figure(figsize=(24, 12))
sb.barplot(x="revenue", y="film", data= df)
# Out:
# <AxesSubplot:xlabel='revenue', ylabel='film'>
# D:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 20843 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 20336 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 21127 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 22580 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 29256 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 12300 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 39740 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 28357 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 12398 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 20995 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 12301 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 28961 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 38480 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 21015 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 36554 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 32232 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 23004 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 23376 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 29273 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 26228 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 38597 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 38598 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 20843 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 20336 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 21127 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 22580 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 29256 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 12300 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 39740 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 28357 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 12398 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 20995 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 12301 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 28961 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 38480 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 21015 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 36554 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 32232 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 23004 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 23376 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 29273 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 26228 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 38597 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 38598 missing from current font.
#   font.set_text(s, 0, flags=flags)
